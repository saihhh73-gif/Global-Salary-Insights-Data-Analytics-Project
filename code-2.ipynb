# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("jobs_in_data_2024.csv") # loading the dataset into a pandas DataFrame

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14199 entries, 0 to 14198
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14199 non-null  int64
#  1   experience_level    14199 non-null  str
#  2   employment_type     14199 non-null  str
#  3   job_title           14199 non-null  str
#  4   salary              14199 non-null  int64
#  5   salary_currency     14199 non-null  str
#  6   salary_in_usd       14199 non-null  int64
#  7   employee_residence  14199 non-null  str
#  8   work_setting        14199 non-null  str
#  9   company_location    14199 non-null  str
#  10  company_size        14199 non-null  str
#  11  job_category        14199 non-null  str
# dtypes: int64(3), str(9)
# memory usage: 2.5 MB

# %%
df.head()
# Out:
#    work_year experience_level employment_type               job_title  salary  \
# 0       2024      Entry-level       Freelance  Applied Data Scientist   30000
# 1       2024        Executive       Full-time   Business Intelligence  230000
# 2       2024        Executive       Full-time   Business Intelligence  176900
# 3       2024           Senior       Full-time          Data Architect  171210
# 4       2024           Senior       Full-time          Data Architect   92190
#
#   salary_currency  salary_in_usd employee_residence work_setting  \
# 0             USD          30000     United Kingdom       Remote
# 1             USD         230000      United States    In-person
# 2             USD         176900      United States    In-person
# 3             USD         171210             Canada    In-person
# 4             USD          92190             Canada    In-person
#
#   company_location company_size                    job_category
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# work_setting          0
# company_location      0
# company_size          0
# job_category          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'work_setting', 'company_location', 'company_size', 'job_category'],
#       dtype='str')

# %%
df.duplicated().sum() #checking for duplicate rows where all the values are same in all the columns or not
# Out:
# np.int64(5493)

# %%
df.shape
# Out:
# (14199, 12)

# %%
df[df.duplicated()].head(10) ## checking the first 10 duplicate rows where all the values are same in all the columns or not
# Out:
#      work_year experience_level employment_type           job_title  salary  \
# 61        2024           Senior       Full-time      Data Scientist  190000
# 62        2024           Senior       Full-time      Data Scientist  155000
# 124       2024           Senior       Full-time      Data Scientist   70000
# 143       2024           Senior       Full-time  Research Scientist  234000
# 144       2024           Senior       Full-time  Research Scientist  146000
# 183       2024           Senior       Full-time      Data Developer   50000
# 191       2024      Entry-level       Full-time        Data Analyst   80000
# 197       2024      Entry-level       Full-time        Data Analyst   26800
# 224       2024           Senior       Full-time      Data Scientist  130000
# 251       2024           Senior       Full-time      Data Scientist  180000
#
#     salary_currency  salary_in_usd employee_residence work_setting  \
# ...

# %%
df=df.drop(columns=["salary"]) ##deleting the salary column as it is not required for analysis

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_currency', 'salary_in_usd', 'employee_residence',
#        'work_setting', 'company_location', 'company_size', 'job_category'],
#       dtype='str')

# %%
df["experience_level"].unique()
df["job_title"].unique()
df["company_location"].unique()
df["job_category"].unique()
# Out:
# <ArrowStringArray>
# [     'Data Science and Research',           'BI and Visualization',
#  'Data Architecture and Modeling',                  'Data Analysis',
#                'Data Engineering',      'Leadership and Management',
#     'Data Quality and Operations',        'Machine Learning and AI',
#              'Cloud and Database',   'Data Management and Strategy']
# Length: 10, dtype: str

# %%
plt.figure(figsize=(8,6))
plt.bar(df["experience_level"].value_counts().index,df['experience_level'].value_counts().values)
plt.title("Experience Level Distribution")
plt.xlabel("Experience Level")
plt.ylabel("Count")
plt.show()

# %%
df.to_csv("cleaned_dataset.csv",index=False) # saving the cleaned dataset to a new CSV file without the index column
print("Saved the cleaned dataset to 'cleaned_dataset.csv'.")
# Out:
# Saved the cleaned dataset to 'cleaned_dataset.csv'.

# %%
import os
print(os.getcwd())  # Get the current working directory
# Out:
# c:\Users\saihh\OneDrive\Documents\data analysis\PROJECT 2
